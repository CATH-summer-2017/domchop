# %%
# %load_ext line_profiler
# %lprun -f visualise visualise(ax,'pong_minimal-s5L0',winwid=wid)
# Out:
# UsageError: Could not find function u'visualise'.
# NameError: name 'visualise' is not defined

# %%
#!/usr/bin/env python

# Example for 'atom' objects


# env = environ()
# #env.io.atom_files_directory = ['../atom_files']
# env.io.atom_files_directory = ['../pdbs']
# env.libs.topology.read(file='$(LIB)/top_heav.lib')
# env.libs.parameters.read(file='$(LIB)/par.lib')


# pdbfile = "../pdbs/4xz8A_chop"
# nDOPE_correct = -1.675

# nDOPE_lst = [('4xz8A_chop', -1.675),
# \t\t\t\t]

# def get_nDOPE( pdbfile, env = env):

import argparse

# parser = argparse.ArgumentParser(description='Short sample app')
# parser.add_argument('-r','--makeref', action="store_true", default=False, dest='newref',
# \t\t\t\t\thelp="Calculate reference nDOPE for structures in ../pdbs/ using cuurent algorithm and store them to ''ref_nDOPEs.csv'' ")
# parser.add_argument('-i','--input', action="store", default=None, dest="input_directory",
# \t\t\t\t\thelp='Input directory containing PDB to test')
# # parser.add_argument('-c', action="store", dest="c", type=int)
# args =  parser.parse_args()

import sys,os,site
# reload(site)
sys.path.append("/home/shouldsee/Documents/repos/cathdb/domchop")
# sys.path.append(os.path.abspath(
# \t\t\t\t\t\t\t\tos.path.join(
# \t\t\t\t\t\t\t\t\tos.path.realpath('$repos/cathdb/domchop/tests/'),
# \t\t\t\t\t\t\t\t\t os.pardir,
# \t\t\t\t\t\t\t\t\t os.pardir)
# \t\t\t\t\t\t\t\t)
# \t\t\t\t)

# for x in sys.path:
# \tprint(x)
# cwd = os.getcwd();

import unittest
from domutil.util import get_nDOPE

# %%
class testcase(unittest.TestCase):
    def test(self):
        # mdl = complete_pdb(env, pdbfile)
        # self.fail('what\'s this???')
        pass
    def test_modeller(self):    
        try:
            from modeller import *
            from modeller.scripts import complete_pdb
        except Exception as e:
            self.fail('Modeller is not installed or configured and raised exception:  ' + str(e) +'\n try running \'source config_modeller.sh\' ')
        else:
            print("modeller module is loaded successfully")
            pass

    def test_dope(self):
        from modeller import log 
        log.none()  ### comment this line to recover verbosity to debug
        import csv
        fname = "ref_DOPEs.csv";
        # if not os.path.isfile(fname): ### Create log file if not existed
        #     open(fname, "w").close();

        with open(fname, "r") as f:
            c = csv.reader(f);
            nDOPE_lst = list(c);
            i = 0;
            imax = len(nDOPE_lst)
            for pdbfile, nDOPE_correct in nDOPE_lst:
                print("\n\n//Testing structure from %s" % pdbfile)
                nDOPE = get_nDOPE(pdbfile);
                nDOPE_correct = float(nDOPE_correct)
                errmsg = "nDOPE for %s is incorrect being %.3f, should be %.3f"%( pdbfile, nDOPE, nDOPE_correct);
                self.assertAlmostEqual(nDOPE, nDOPE_correct, places=3, msg=errmsg, delta=None)
                i = i + 1
                print("%d of %d structure-nDOPE pairs passed tests" % ( i, imax))

            if i == 0:
                self.fail("No test set availabe")
            print("All pdbs yielded expected nDOPE z-scores")

            
class Object(object):
    pass
args = Object()
args.input_directory = None;
args.newref = 1
print(args.input_directory)
# Out:
# None
# <ipython-input-19-03b7e8910db8>:6: SyntaxWarning: import * only allowed at module level
#   def test_modeller(self):

# %%
if __name__ == '__main__':
    
    if args.newref or args.input_directory:
        from modeller import *
        from modeller.scripts import complete_pdb
        # from domutil.util import *
        env = environ();

        if not args.input_directory:
            mypath = "../pdbs/"
        else:
            # mypath = input_directory;#
            mypath = os.path.abspath(args.input_directory)

        # print(mypath)
        from os import listdir
        from os.path import isfile, join

        if os.path.isdir(mypath):
            onlyfiles = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]
        else:
            onlyfiles = [mypath]

        onlyfiles = sorted(onlyfiles)
        nDOPEs = [];
        tested_files = [];


        # print(onlyfiles)

        wait = 0;
        waitname = "3p9dG03";
        reset = 0;

        if reset:
            open("ref_DOPEs.csv","w").close()

        import csv

        with open("ref_DOPEs.csv", "a") as f:
            c = csv.writer(f)

            for pdbfile in onlyfiles:
                pdbname = os.path.basename(pdbfile);
                if pdbfile.split(".")[-1] in ["bak"] or wait:
                    # onlyfiles.pop(pdbfile);
                    if pdbname == waitname:
                        wait = 0;
                    continue
                print("\n\n//Testing structure from %s" % pdbfile)
                nDOPE = get_nDOPE( join(pdbfile), env = env)
                nDOPEs.append( nDOPE );
                tested_files.append( pdbname );
                c.writerow( [pdbname, nDOPE] )
                f.flush()
            
            # for row_vals in zip(tested_files, nDOPEs):
            #     # row = "\t".join(row_vals)+"\n"
            #     c.writerow(row_vals);

    else:
        unittest.main();

        # print(zip(onlyfiles, nDOPEs))



# print("Normalised z-score for DOPE (nDOPE) = %.3f " %( nDOPE) )

# # 'mdl.atoms' is a list of all atoms in the model
# print("Name of C-alpha atom in residue 4 in chain A: %s " \
#       % mdl.atoms['CA:4:A'].name)
# a = mdl.atoms[0]
# print("Coordinates of first atom: %.3f, %.3f, %.3f" % (a.x, a.y, a.z))

# # Each 'residue' object lists its own atoms, as does each chain
# a = mdl.residues['10:A'].atoms[0]
# print("Biso for first atom in residue 10 in chain A %.3f" % a.biso)

# a = mdl.chains[0].residues[-1].atoms[-1]
# print("Biso for last atom in last residue in first chain: %.3f" % a.biso)
# Out:
#                          MODELLER 9.18, 2017/02/17, r11002
#
#      PROTEIN STRUCTURE MODELLING BY SATISFACTION OF SPATIAL RESTRAINTS
#
#
#                      Copyright(c) 1989-2017 Andrej Sali
#                             All Rights Reserved
#
#                              Written by A. Sali
#                                with help from
#               B. Webb, M.S. Madhusudhan, M-Y. Shen, G.Q. Dong,
#           M.A. Marti-Renom, N. Eswar, F. Alber, M. Topf, B. Oliva,
#              A. Fiser, R. Sanchez, B. Yerkovich, A. Badretdinov,
#                      F. Melo, J.P. Overington, E. Feyfant
#                  University of California, San Francisco, USA
#                     Rockefeller University, New York, USA
#                       Harvard University, Cambridge, USA
#                    Imperial Cancer Research Fund, London, UK
#               Birkbeck College, University of London, London, UK
#
#
# Kind, OS, HostName, Kernel, Processor: 4, Linux shouldsee-asus 4.4.0-81-generic x86_64
# Date and time of compilation         : 2017/02/17 14:29:39
# MODELLER executable type             : x86_64-intel8
# Job starting time (YY/MM/DD HH:MM:SS): 2017/07/04 14:29:04
#
#
#
# //Testing structure from ../pdbs/2odlA_chop_cath
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ARG:OXT  ARG
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      781
# Number of all, selected real atoms                :     6033    6033
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):  1314264
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -92256.4375
#
#
#
#
# << end of ENERGY.
# DOPE score               : -92256.437500
# >> Normalized DOPE z score: -2.020
#
#
# //Testing structure from ../pdbs/2odlA_sup
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ARG:OXT  ARG
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
# iatmcls_286W> MODEL atom not classified:  ASP:OXT  ASP
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
# Number of all residues in MODEL                   :     1602Number of all, selected pseudo atoms              :        0       0COVALENT_CYS                                      :        FNumber of non-bonded pairs (excluding 1-2,1-3,1-4):  6007982Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390COULOMB_JONES_SWITCH                              :    6.500   7.500NLOGN_USE                                         :       15DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       TRADII_FACTOR                                      :    0.820
#
#
# << end of ENERGY.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-97bd260d9e28> in <module>()
#      49                     continue
#      50                 print("\n\n//Testing structure from %s" % pdbfile)
# ---> 51                 nDOPE = get_nDOPE( join(pdbfile), env=None)
#      52                 nDOPEs.append( nDOPE );
#      53                 tested_files.append( pdbname );
#
# /home/shouldsee/Documents/repos/cathdb/domchop/domutil/util.pyc in get_nDOPE(pdbfile, env)
#      16
#      17         mdl = complete_pdb(env, pdbfile)
# ---> 18         nDOPE = mdl.assess_normalized_dope()
#      19         return nDOPE
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/model.pyc in assess_normalized_dope(self)
#     333         from modeller import normalized_dope
#     334         sel = selection(self)
# --> 335         dope_score = sel.assess_dope()
#     336         scorer = normalized_dope.DOPEScorer(self)
#     337         z_score = scorer.get_z_score(dope_score)
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/selection.pyc in assess_dope(self, **vars)
#     610     def assess_dope(self, **vars):
#     611         """Assess the selection with the DOPE potential"""
# --> 612         return self._dope_energy(self.get_dope_potential(), "DOPE", **vars)
#     613
#     614     def assess_dopehr(self, **vars):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/selection.pyc in _dope_energy(self, gprsr, name, output, residue_span_range, schedule_scale, **vars)
#     671                 self.energy(edat=edat, residue_span_range=residue_span_range,
#     672                             output=output, schedule_scale=schedule_scale,
# --> 673                             **vars)
#     674         finally:
#     675             mdl.group_restraints = old_gprsr
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/selection.pyc in energy(self, asgl_output, normalize_profile, residue_span_range, output, file, viol_report_cut, viol_report_cut2, smoothing_window, schedule_scale, edat)
#     581                                smoothing_window, viol_report_cut,
#     582                                viol_report_cut2, schedule_scale)
# --> 583         terms = physical.from_list(terms)
#     584         return (molpdf, terms)
#     585
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/physical.pyc in from_list(lval)
#     120 def from_list(lval):
#     121     """Initialize an object from a Modeller internal list of values"""
# --> 122     obj = values(default=None)
#     123     obj.set_from_list(lval)
#     124     return obj
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/physical.pyc in __init__(self, default, **keys)
#      32         self._default = default
#      33         self._dict = {}
# ---> 34         for (term,val) in keys.items():
#      35             term = eval("%s" % term)
#      36             self[term] = val
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      63     def write(self, text):
#      64         """Write directly to the logfile"""
# ---> 65         print(text)
#      66
#      67     def __wrterr(self, routine, code, message):
#
# /home/shouldsee/Documents/repos/modeller/modlib/modeller/util/logger.pyc in write(self, text)
#      61         self.write(text)
#      62
# ---> 63     def write(self, text):
#      64         """Write directly to the logfile"""
#      65         print(text)
#
# KeyboardInterrupt:

# %%
env = environ();
def main():
        wait = 0;
        waitname = "3p9dG03";
        reset = 0;

        if reset:
            open("ref_DOPEs.csv","w").close()

        import csv

        with open("ref_DOPEs.csv", "a") as f:
            c = csv.writer(f)

            for pdbfile in onlyfiles:
                pdbname = os.path.basename(pdbfile);
                if pdbfile.split(".")[-1] in ["bak"] or wait:
                    # onlyfiles.pop(pdbfile);
                    if pdbname == waitname:
                        wait = 0;
                    continue
                print("\n\n//Testing structure from %s" % pdbfile)
                try:
                    nDOPE = get_nDOPE( join(pdbfile), env = env)
                except:
                    print("can't process", pdbfile)
#                     break
                    
                nDOPEs.append( nDOPE );
                tested_files.append( pdbname );
                c.writerow( [pdbname, nDOPE] )
                f.flush()

# %load_ext line_profiler
# %lprun -f main main()
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
#
#
# //Testing structure from ../pdbs/2odlA_chop_cath
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ARG:OXT  ARG
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      781
# Number of all, selected real atoms                :     6033    6033
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):  1314264
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -92256.4375
#
#
#
#
# << end of ENERGY.
# DOPE score               : -92256.437500
# >> Normalized DOPE z score: -2.020
#
#
# //Testing structure from ../pdbs/2odlA_sup
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ARG:OXT  ARG
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
# iatmcls_286W> MODEL atom not classified:  ASP:OXT  ASP
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :     1602
# Number of all, selected real atoms                :    12179   12179
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):  6007982
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -11318.4668
#
#
#
#
# << end of ENERGY.
# DOPE score               : -11318.466797
# >> Normalized DOPE z score: 6.043
#
#
# //Testing structure from ../pdbs/4ufqA
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      211
# Number of all, selected real atoms                :     1488    1488
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   124947
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -10730.4756
#
#
#
#
# << end of ENERGY.
# DOPE score               : -10730.475586
# >> Normalized DOPE z score: 2.015
#
#
# //Testing structure from ../pdbs/4ufq_bio.catpdb
# read_to_681_> topology.submodel read from topology file:        3
# relabel_387W> Model has multiple chains, and they do not all have a unique
#               chain ID. Suggest you relabel them as A, B, C, etc.
# relabel_469W> At least one residue number in the model is duplicated.
#               (First duplication is residue "    7", chain " B".)
#               Suggest you renumber the residues and/or chains to
#               avoid selecting the wrong residues (e.g. with model_segment).
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      633
# Number of all, selected real atoms                :     4473    4473
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):  1003121
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -69062.0078
#
#
#
#
# << end of ENERGY.
# DOPE score               : -69062.007812
# >> Normalized DOPE z score: -1.326
#
#
# //Testing structure from ../pdbs/4ufq_bio.pdb
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      211
# Number of all, selected real atoms                :     1491    1491
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   125887
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -10849.1201
#
#
#
#
# << end of ENERGY.
# DOPE score               : -10849.120117
# >> Normalized DOPE z score: 1.994
#
#
# //Testing structure from ../pdbs/4ui9X
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  PRO:OXT  PRO
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      484
# Number of all, selected real atoms                :     3802    3802
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   690367
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -56193.9609
#
#
#
#
# << end of ENERGY.
# DOPE score               : -56193.960938
# >> Normalized DOPE z score: -0.551
#
#
# //Testing structure from ../pdbs/4xz8A_chop
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  PRO:OXT  PRO
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      473
# Number of all, selected real atoms                :     3694    3694
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   775141
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -59435.7969
#
#
#
#
# << end of ENERGY.
# DOPE score               : -59435.796875
# >> Normalized DOPE z score: -1.675
#
#
# //Testing structure from ../pdbs/4yv4
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  PHE:OXT  PHE
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# iatmcls_286W> MODEL atom not classified:  GLN:OXT  GLN
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      427
# Number of all, selected real atoms                :     3567    3567
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   573977
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -52566.8008
#
#
#
#
# << end of ENERGY.
# DOPE score               : -52566.800781
# >> Normalized DOPE z score: -2.507
#
#
# //Testing structure from ../pdbs/4yv4G
# read_to_681_> topology.submodel read from topology file:        3
#
# getf_______W> RTF restraint not found in the atoms list:
#               residue type, indices:    13     1
#               atom names           : N     -C    CA    CD
#               atom indices         :     1     0     2     3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  THR:OXT  THR
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :       56
# Number of all, selected real atoms                :      468     468
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):    31312
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :       -5034.3955
#
#
#
#
# << end of ENERGY.
# DOPE score               : -5034.395508
# >> Normalized DOPE z score: -2.254
#
#
# //Testing structure from ../pdbs/5kk3
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      576
# Number of all, selected real atoms                :     4230    4230
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   981612
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -79997.7344
#
#
#
#
# << end of ENERGY.
# DOPE score               : -79997.734375
# >> Normalized DOPE z score: -1.506
#
#
# //Testing structure from ../pdbs/5kk3_AJ
# read_to_681_> topology.submodel read from topology file:        3
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# iatmcls_286W> MODEL atom not classified:  ALA:OXT  ALA
# preppdf_453W> No fixed restraints selected; there may be some dynamic ones.
# preppdf_454W> Restraints file was probably not read; use restraints.append().
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :       64
# Number of all, selected real atoms                :      470     470
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :        0       0
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):    28012
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :       -2771.0100
#
#
#
#
# << end of ENERGY.
# DOPE score               : -2771.010010
# >> Normalized DOPE z score: 3.271
#
#
# //Testing structure from ../pdbs/ref_DOPEs.csv
# read_to_681_> topology.submodel read from topology file:        3
# pdbnam_____E> Filename for PDB code not found: ../pdbs/ref_DOPEs.csv
#               Directories: ../pdbs
#               Extensions : :.atm:.pdb:.ent:.cif:.crd
#               (Also tried prepending 'pdb', looking for .Z, .gz, .bz2, .7z, .xz,
#               and trying PDB-style subdirectories - e.g. ab for pdb1abc.ent)
#
# ("can't process", '../pdbs/ref_DOPEs.csv')

# %% [raw]
# #### Profiler result
#
# # Timer unit: 1e-06 s
#
# Total time: 12.4703 s
# File: <ipython-input-27-19c264d8bf47>
# Function: main at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def main():
#      3         1            2      2.0      0.0          wait = 0;
#      4         1            1      1.0      0.0          waitname = "3p9dG03";
#      5         1            1      1.0      0.0          reset = 0;
#      6
#      7         1            1      1.0      0.0          if reset:
#      8                                                       open("ref_DOPEs.csv","w").close()
#      9
#     10         1            4      4.0      0.0          import csv
#     11
#     12         1           46     46.0      0.0          with open("ref_DOPEs.csv", "a") as f:
#     13         1           12     12.0      0.0              c = csv.writer(f)
#     14
#     15        14           53      3.8      0.0              for pdbfile in onlyfiles:
#     16        13          116      8.9      0.0                  pdbname = os.path.basename(pdbfile);
#     17        13          101      7.8      0.0                  if pdbfile.split(".")[-1] in ["bak"] or wait:
#     18                                                               # onlyfiles.pop(pdbfile);
#     19         1            1      1.0      0.0                      if pdbname == waitname:
#     20                                                                   wait = 0;
#     21                                                               continue
#     22        12         8685    723.8      0.1                  print("\n\n//Testing structure from %s" % pdbfile)
#     23        12           21      1.8      0.0                  try:
#     24        12     12459657 1038304.8     99.9                      nDOPE = get_nDOPE( join(pdbfile), env = env)
#     25         1            3      3.0      0.0                  except:
#     26         1          146    146.0      0.0                      print("can't process", pdbfile)
#     27                                           #                     break
#     28
#     29        12           46      3.8      0.0                  nDOPEs.append( nDOPE );
#     30        12           16      1.3      0.0                  tested_files.append( pdbname );
#     31        12          328     27.3      0.0                  c.writerow( [pdbname, nDOPE] )
#     32        12         1046     87.2      0.0                  f.flush()
